# %%
#!pip install simple_salesforce
#!pip install pymysql
#!pip install sqlalchemy

# %%
import json
from sqlalchemy import create_engine
from datetime import date
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Make sure to use your own `config.py` file. Consider ensuring that these variable names are in sync
from config import sf_username, sf_password, sf_security_token
from config import remote_db_endpoint, remote_db_port
from config import remote_db_name, remote_db_user, remote_db_pwd

# %%
from simple_salesforce import Salesforce
sf = Salesforce(username=sf_username, password=sf_password, security_token=sf_security_token)

# %%
engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
conn = engine.connect()

# %% [markdown]
# ## Prepare ETL for the Student data

# %%
student_data_df = pd.read_sql('select * from student', conn)
student_data_df.head()
# Out:
#    ID_Student StudentID  LastName  FirstName MiddleName BirthDate Gender
# 0          33  25004961  Dartling    Heather      Alice      None      F
# 1          34  25003514  Dartling       Lana    Cecille      None      F
# 2          35  25005833  Dartling    Jessica    Dorothy      None      F
# 3          36  25002589  Dartling   Kimberly  Genevieve      None      F
# 4          37  25007185  Dartling  Katherine   Lynnette      None      F

# %%
student_data_df.rename(columns={
    'ID_Student': 'Student_ID__c',
    'StudentID': 'Student_No__c',
    'LastName': 'LastName__c',
    'FirstName': 'FirstName__c',
    'MiddleName': 'MiddleName__c',
    'BirthDate': 'BirthDate__c',
    'Gender': 'Gender__c'
}, inplace=True)

student_data_df.head()
# Out:
#    Student_ID__c Student_No__c LastName__c FirstName__c MiddleName__c  \
# 0             33      25004961    Dartling      Heather         Alice
# 1             34      25003514    Dartling         Lana       Cecille
# 2             35      25005833    Dartling      Jessica       Dorothy
# 3             36      25002589    Dartling     Kimberly     Genevieve
# 4             37      25007185    Dartling    Katherine      Lynnette
#
#   BirthDate__c Gender__c
# 0         None         F
# 1         None         F
# 2         None         F
# 3         None         F
# 4         None         F

# %%
# select columns
#student_data_df = student_data_df[['ID_Student__c','LastName__c','FirstName__c', 'MiddleName__c', 'BirthDate__c', 'Gender__c']]
#student_data_df.head()

# %%
# Create record - list of dictionaries
student_data_records = student_data_df.to_dict('records')
student_data_records
# Out:
# [{'Student_ID__c': 33,
#   'Student_No__c': '25004961',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Heather',
#   'MiddleName__c': 'Alice',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 34,
#   'Student_No__c': '25003514',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Lana',
#   'MiddleName__c': 'Cecille',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 35,
#   'Student_No__c': '25005833',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Jessica',
#   'MiddleName__c': 'Dorothy',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 36,
#   'Student_No__c': '25002589',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Kimberly',
#   'MiddleName__c': 'Genevieve',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 37,
#   'Student_No__c': '25007185',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Katherine',
#   'MiddleName__c': 'Lynnette',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 38,
#   'Student_No__c': '25006014',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Precious',
#   'MiddleName__c': 'Mariette',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 39,
#   'Student_No__c': '25007528',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Cindy',
#   'MiddleName__c': 'Patty',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 40,
#   'Student_No__c': '25003778',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Carlie',
#   'MiddleName__c': 'Raelene',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 41,
#   'Student_No__c': '25003605',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Clementine',
#   'MiddleName__c': 'Kendall',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 42,
#   'Student_No__c': '25002056',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Amirah',
#   'MiddleName__c': 'Angela',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 43,
#   'Student_No__c': '25004152',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Sarah',
#   'MiddleName__c': 'Serita',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 44,
#   'Student_No__c': '25004097',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Julia',
#   'MiddleName__c': 'Claire',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Student_ID__c': 45,
#   'Student_No__c': '25002311',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Jimmy',
#   'MiddleName__c': 'Carlton',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 46,
#   'Student_No__c': '25005602',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Joseph',
#   'MiddleName__c': 'Cyrus',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 47,
#   'Student_No__c': '25006805',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Perry',
#   'MiddleName__c': 'Danny',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 48,
#   'Student_No__c': '25006947',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Todd',
#   'MiddleName__c': 'Darren',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 49,
#   'Student_No__c': '25002714',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Tom',
#   'MiddleName__c': 'Deangelo',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 50,
#   'Student_No__c': '25005284',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Aditya',
#   'MiddleName__c': 'Dion',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 51,
#   'Student_No__c': '25006348',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Chris',
#   'MiddleName__c': 'Floyd',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 52,
#   'Student_No__c': '25002555',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Christopher',
#   'MiddleName__c': 'Horace',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 53,
#   'Student_No__c': '25005250',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Cole',
#   'MiddleName__c': 'Lino',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 54,
#   'Student_No__c': '25002325',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'David',
#   'MiddleName__c': 'Lucien',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 55,
#   'Student_No__c': '25003773',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Dino',
#   'MiddleName__c': 'Lynwood',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 56,
#   'Student_No__c': '25003936',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'John',
#   'MiddleName__c': 'Noelle',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 57,
#   'Student_No__c': '25005443',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Michael',
#   'MiddleName__c': 'Parker',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 58,
#   'Student_No__c': '25006762',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Patrick',
#   'MiddleName__c': 'Richard',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 59,
#   'Student_No__c': '25006027',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Robert',
#   'MiddleName__c': 'Riley',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 60,
#   'Student_No__c': '25002876',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Trevor',
#   'MiddleName__c': 'Seth',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 61,
#   'Student_No__c': '25007333',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Yasir',
#   'MiddleName__c': 'Solomon',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Student_ID__c': 62,
#   'Student_No__c': '25007334',
#   'LastName__c': 'Dartling',
#   'FirstName__c': 'Kevin',
#   'MiddleName__c': 'Stewart',
#   'BirthDate__c': None,
#   'Gender__c': 'M'}]

# %%
# Migrate data to Salesforce
for rec in student_data_records:
    record = {
        'Student_ID__c': rec['Student_ID__c'],
        'Student_No__c': rec['Student_No__c'],
        'LastName__c': rec['LastName__c'],
        'FirstName__c': rec['FirstName__c'],
        'MiddleName__c': rec['MiddleName__c'],
        'BirthDate__c': rec['BirthDate__c'],
        'Gender__c': rec['Gender__c']
    }
    
    try:
        sf.Student__c.create(record)
    except Exception as e:
        print(e)

# %% [markdown]
# ## Create Student Lookup Table

# %%
student_lookup_list = []

data = sf.query_all_iter("select Student_ID__c, Name from Student__c")
for row in data:
    rec = {
        "ID_Student__c": row['Name'],
        "Student_ID__c": row['Student_ID__c']
    }
    student_lookup_list.append(rec)

student_lookup_list
# Out:
# [{'ID_Student__c': 'a034x000002idey', 'Student_ID__c': '37'},
#  {'ID_Student__c': 'a034x000002idfw', 'Student_ID__c': '49'},
#  {'ID_Student__c': 'a034x000002idgB', 'Student_ID__c': '52'},
#  {'ID_Student__c': 'a034x000002idfh', 'Student_ID__c': '46'},
#  {'ID_Student__c': 'a034x000002idga', 'Student_ID__c': '57'},
#  {'ID_Student__c': 'a034x000002idee', 'Student_ID__c': '33'},
#  {'ID_Student__c': 'a034x000002idg1', 'Student_ID__c': '50'},
#  {'ID_Student__c': 'a034x000002idfr', 'Student_ID__c': '48'},
#  {'ID_Student__c': 'a034x000002idgp', 'Student_ID__c': '60'},
#  {'ID_Student__c': 'a034x000002idfN', 'Student_ID__c': '42'},
#  {'ID_Student__c': 'a034x000002idf8', 'Student_ID__c': '39'},
#  {'ID_Student__c': 'a034x000002idgf', 'Student_ID__c': '58'},
#  {'ID_Student__c': 'a034x000002idej', 'Student_ID__c': '34'},
#  {'ID_Student__c': 'a034x000002idf3', 'Student_ID__c': '38'},
#  {'ID_Student__c': 'a034x000002idfI', 'Student_ID__c': '41'},
#  {'ID_Student__c': 'a034x000002idgL', 'Student_ID__c': '54'},
#  {'ID_Student__c': 'a034x000002idgk', 'Student_ID__c': '59'},
#  {'ID_Student__c': 'a034x000002idgu', 'Student_ID__c': '61'},
#  {'ID_Student__c': 'a034x000002idgG', 'Student_ID__c': '53'},
#  {'ID_Student__c': 'a034x000002idfS', 'Student_ID__c': '43'},
#  {'ID_Student__c': 'a034x000002idfD', 'Student_ID__c': '40'},
#  {'ID_Student__c': 'a034x000002idg6', 'Student_ID__c': '51'},
#  {'ID_Student__c': 'a034x000002idgQ', 'Student_ID__c': '55'},
#  {'ID_Student__c': 'a034x000002idfX', 'Student_ID__c': '44'},
#  {'ID_Student__c': 'a034x000002ideo', 'Student_ID__c': '35'},
#  {'ID_Student__c': 'a034x000002idfc', 'Student_ID__c': '45'},
#  {'ID_Student__c': 'a034x000002idfm', 'Student_ID__c': '47'},
#  {'ID_Student__c': 'a034x000002idgV', 'Student_ID__c': '56'},
#  {'ID_Student__c': 'a034x000002idet', 'Student_ID__c': '36'},
#  {'ID_Student__c': 'a034x000002idgz', 'Student_ID__c': '62'}]

# %%
student_lookup_df = pd.DataFrame(student_lookup_list)
student_lookup_df.head()
# Out:
#      ID_Student__c Student_ID__c
# 0  a034x000002idey            37
# 1  a034x000002idfw            49
# 2  a034x000002idgB            52
# 3  a034x000002idfh            46
# 4  a034x000002idga            57

# %% [markdown]
# ### Create Class lookup table

# %%
class_lookup_list = []

data = sf.query_all_iter('select ID_Class__c, Name from Class__c')
for row in data:
    rec = {
        "Class_ID__c": row['Name'],
        "ID_Class__c": row['ID_Class__c']
    }
    
    class_lookup_list.append(rec)

class_lookup_list
# Out:
# [{'Class_ID__c': 'a014x000008Tj9e', 'ID_Class__c': '2'},
#  {'Class_ID__c': 'a014x000008Tj9Z', 'ID_Class__c': '1'},
#  {'Class_ID__c': 'a014x000008Tj9j', 'ID_Class__c': '3'},
#  {'Class_ID__c': 'a014x000008Tj9o', 'ID_Class__c': '4'}]

# %%
class_lookup_df = pd.DataFrame(class_lookup_list)
class_lookup_df.head()
# Out:
#        Class_ID__c ID_Class__c
# 0  a014x000008Tj9e           2
# 1  a014x000008Tj9Z           1
# 2  a014x000008Tj9j           3
# 3  a014x000008Tj9o           4

# %%
class_lookup_df['ID_Class__c'] = class_lookup_df['ID_Class__c'].astype(str)
class_lookup_df.head()
# Out:
#        Class_ID__c ID_Class__c
# 0  a014x000008Tj9e           2
# 1  a014x000008Tj9Z           1
# 2  a014x000008Tj9j           3
# 3  a014x000008Tj9o           4

# %% [markdown]
# #### Query the Classparticipant table from MySQL

# %%
query = '''
   select 
      *
   from classparticipant

'''
classparticipant_data_df = pd.read_sql(query, conn)
classparticipant_data_df.head()
# Out:
#    ID_ClassParticipant  ID_Student  ID_Class   StartDate EndDate
# 0                    1          33         1  2020-09-16    None
# 1                    2          34         1  2020-09-16    None
# 2                    3          35         1  2020-09-16    None
# 3                    4          62         1  2020-09-16    None
# 4                    5          36         1  2020-09-16    None

# %%
classparticipant_data_df.rename(columns={
    'ID_ClassParticipant':'ID_ClassParticipant__c',
    'ID_Student':'Student_ID__c',
    'ID_Class':'ID_Class__c',
    'StartDate':'StartDate__c',
    'EndDate':'EndDate__c'
}, inplace=True)

classparticipant_data_df.head()
# Out:
#    ID_ClassParticipant__c  Student_ID__c  ID_Class__c StartDate__c EndDate__c
# 0                       1             33            1   2020-09-16       None
# 1                       2             34            1   2020-09-16       None
# 2                       3             35            1   2020-09-16       None
# 3                       4             62            1   2020-09-16       None
# 4                       5             36            1   2020-09-16       None

# %%
#classparticipant_data_df = classparticipant_data_df[['ID_Student__c', 'ID_ClassParticipant__c', 'ID_Class__c', 'StartDate__c', 'EndDate__c']]
#classparticipant_data_df.head()

# %%
classparticipant_data_df['Student_ID__c'] = classparticipant_data_df['Student_ID__c'].astype(str)
classparticipant_data_df.head()
# Out:
#    ID_ClassParticipant__c Student_ID__c  ID_Class__c StartDate__c EndDate__c
# 0                       1            33            1   2020-09-16       None
# 1                       2            34            1   2020-09-16       None
# 2                       3            35            1   2020-09-16       None
# 3                       4            62            1   2020-09-16       None
# 4                       5            36            1   2020-09-16       None

# %% [markdown]
# ## Join the Class DataFrame with the Course lookup table
# This join is necessary to successfully lookup the foreign key for the Course table

# %%
student_lookup_df.head()
# Out:
#      ID_Student__c Student_ID__c
# 0  a034x000002idYG            48
# 1  a034x000002idYz            57
# 2  a034x000002idYQ            50
# 3  a034x000002idXh            41
# 4  a034x000002idXI            36

# %%
class_lookup_df.head()
# Out:
#        Class_ID__c ID_Class__c
# 0  a014x000008Tj9e           2
# 1  a014x000008Tj9Z           1
# 2  a014x000008Tj9j           3
# 3  a014x000008Tj9o           4

# %%
classparticipant_data_df.head()
# Out:
#    ID_ClassParticipant__c Student_ID__c  ID_Class__c StartDate__c EndDate__c
# 0                       1            33            1   2020-09-16       None
# 1                       2            34            1   2020-09-16       None
# 2                       3            35            1   2020-09-16       None
# 3                       4            62            1   2020-09-16       None
# 4                       5            36            1   2020-09-16       None

# %%
classparticipant_data_merge1 = pd.merge(classparticipant_data_df, student_lookup_df, how='left')
classparticipant_data_merge1.head()
# Out:
#    ID_ClassParticipant__c Student_ID__c  ID_Class__c StartDate__c EndDate__c  \
# 0                       1            33            1   2020-09-16       None
# 1                       2            34            1   2020-09-16       None
# 2                       3            35            1   2020-09-16       None
# 3                       4            62            1   2020-09-16       None
# 4                       5            36            1   2020-09-16       None
#
#      ID_Student__c
# 0  a034x000002idee
# 1  a034x000002idej
# 2  a034x000002ideo
# 3  a034x000002idgz
# 4  a034x000002idet

# %%
#class_lookup_list['ID_Class__c'] = class_lookup_list['ID_Class__c'].astype(str)
#class_lookup_list.head()

# %%
classparticipant_data_merge1['ID_Class__c'] = classparticipant_data_merge1['ID_Class__c'].astype(str)
classparticipant_data_merge1.head()
# Out:
#    ID_ClassParticipant__c Student_ID__c ID_Class__c StartDate__c EndDate__c  \
# 0                       1            33           1   2020-09-16       None
# 1                       2            34           1   2020-09-16       None
# 2                       3            35           1   2020-09-16       None
# 3                       4            62           1   2020-09-16       None
# 4                       5            36           1   2020-09-16       None
#
#      ID_Student__c
# 0  a034x000002idee
# 1  a034x000002idej
# 2  a034x000002ideo
# 3  a034x000002idgz
# 4  a034x000002idet

# %%
classparticipant_data_merge2 = pd.merge(classparticipant_data_merge1, class_lookup_df, how='left')
classparticipant_data_merge2.head()
# Out:
#    ID_ClassParticipant__c Student_ID__c ID_Class__c StartDate__c EndDate__c  \
# 0                       1            33           1   2020-09-16       None
# 1                       2            34           1   2020-09-16       None
# 2                       3            35           1   2020-09-16       None
# 3                       4            62           1   2020-09-16       None
# 4                       5            36           1   2020-09-16       None
#
#      ID_Student__c      Class_ID__c
# 0  a034x000002idee  a014x000008Tj9Z
# 1  a034x000002idej  a014x000008Tj9Z
# 2  a034x000002ideo  a014x000008Tj9Z
# 3  a034x000002idgz  a014x000008Tj9Z
# 4  a034x000002idet  a014x000008Tj9Z

# %%
classparticipant_data_merge2['StartDate__c'] = pd.to_datetime(classparticipant_data_merge2['StartDate__c']).dt.date
classparticipant_data_merge2.head()
# Out:
#    ID_ClassParticipant__c Student_ID__c ID_Class__c StartDate__c EndDate__c  \
# 0                       1            33           1   2020-09-16       None
# 1                       2            34           1   2020-09-16       None
# 2                       3            35           1   2020-09-16       None
# 3                       4            62           1   2020-09-16       None
# 4                       5            36           1   2020-09-16       None
#
#      ID_Student__c      Class_ID__c
# 0  a034x000002idee  a014x000008Tj9Z
# 1  a034x000002idej  a014x000008Tj9Z
# 2  a034x000002ideo  a014x000008Tj9Z
# 3  a034x000002idgz  a014x000008Tj9Z
# 4  a034x000002idet  a014x000008Tj9Z

# %%
# Create record
classparticipant_data_records = classparticipant_data_merge2.to_dict(orient='records')
classparticipant_data_records
# Out:
# [{'ID_ClassParticipant__c': 1,
#   'Student_ID__c': '33',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idee',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 2,
#   'Student_ID__c': '34',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idej',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 3,
#   'Student_ID__c': '35',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002ideo',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 4,
#   'Student_ID__c': '62',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idgz',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 5,
#   'Student_ID__c': '36',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idet',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 6,
#   'Student_ID__c': '37',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idey',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 7,
#   'Student_ID__c': '38',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idf3',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 8,
#   'Student_ID__c': '39',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idf8',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 9,
#   'Student_ID__c': '40',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idfD',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 10,
#   'Student_ID__c': '41',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idfI',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 11,
#   'Student_ID__c': '42',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idfN',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 12,
#   'Student_ID__c': '43',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idfS',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 13,
#   'Student_ID__c': '46',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idfh',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 14,
#   'Student_ID__c': '47',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idfm',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 15,
#   'Student_ID__c': '48',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idfr',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 16,
#   'Student_ID__c': '49',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idfw',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 17,
#   'Student_ID__c': '50',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idg1',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 18,
#   'Student_ID__c': '51',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idg6',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 20,
#   'Student_ID__c': '53',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idgG',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 21,
#   'Student_ID__c': '54',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idgL',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 22,
#   'Student_ID__c': '55',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idgQ',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 23,
#   'Student_ID__c': '56',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idgV',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 24,
#   'Student_ID__c': '57',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idga',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 25,
#   'Student_ID__c': '58',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idgf',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 26,
#   'Student_ID__c': '59',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idgk',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 27,
#   'Student_ID__c': '60',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idgp',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 28,
#   'Student_ID__c': '61',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idgu',
#   'Class_ID__c': 'a014x000008Tj9Z'},
#  {'ID_ClassParticipant__c': 29,
#   'Student_ID__c': '44',
#   'ID_Class__c': '1',
#   'StartDate__c': datetime.date(2020, 9, 16),
#   'EndDate__c': None,
#   'ID_Student__c': 'a034x000002idfX',
#   'Class_ID__c': 'a014x000008Tj9Z'}]

# %% [markdown]
# ## Insert `Class` Records into Salesforce

# %%
for rec in classparticipant_data_records:
    
    record = {
        'ID_ClassParticipant__c': rec['ID_ClassParticipant__c'],
        'Student_ID__c': rec['Student_ID__c'],
        'ID_Class__c': rec['ID_Class__c'],
        'StartDate__c': str(rec['StartDate__c']),
        'EndDate__c': str(rec['EndDate__c']),
        'ID_Student__c': rec['ID_Student__c'],
        'Class_ID__c': rec['Class_ID__c']
    }
    
    try:
        sf.Classparticipant__C.create(record)
    except Exception as e:
        print(e)

# %% [markdown]
# ## Example of Deleting Records
#
# Select the IDs of the records first and then process the results.
#
# Ultimately, you want a list of IDs in the end.

# %%
classparticipant_records = sf.query("SELECT Id FROM Classparticipant__c")
recs_to_delete = [{'Id': r['Id']} for r in classparticipant_records['records']]
recs_to_delete
# Out:
# [{'Id': 'a024x000002gVnlAAE'},
#  {'Id': 'a024x000002gVnpAAE'},
#  {'Id': 'a024x000002gVnuAAE'},
#  {'Id': 'a024x000002gVnzAAE'},
#  {'Id': 'a024x000002gVo4AAE'},
#  {'Id': 'a024x000002gVo9AAE'},
#  {'Id': 'a024x000002gVoEAAU'},
#  {'Id': 'a024x000002gVoJAAU'},
#  {'Id': 'a024x000002gVoOAAU'},
#  {'Id': 'a024x000002gVoTAAU'},
#  {'Id': 'a024x000002gVoYAAU'},
#  {'Id': 'a024x000002gVodAAE'},
#  {'Id': 'a024x000002gVoiAAE'},
#  {'Id': 'a024x000002gVonAAE'},
#  {'Id': 'a024x000002gVosAAE'},
#  {'Id': 'a024x000002gVoxAAE'},
#  {'Id': 'a024x000002gVp2AAE'},
#  {'Id': 'a024x000002gVp7AAE'},
#  {'Id': 'a024x000002gVpCAAU'},
#  {'Id': 'a024x000002gVpHAAU'},
#  {'Id': 'a024x000002gVpMAAU'},
#  {'Id': 'a024x000002gVpRAAU'},
#  {'Id': 'a024x000002gVpWAAU'},
#  {'Id': 'a024x000002gVpbAAE'},
#  {'Id': 'a024x000002gVpgAAE'},
#  {'Id': 'a024x000002gVplAAE'},
#  {'Id': 'a024x000002gVpqAAE'},
#  {'Id': 'a024x000002gVpvAAE'}]

# %%
#sf.bulk.Course__c.delete(recs_to_delete)

# %%
for rec in recs_to_delete:
    try:
        sf.classparticipant__c.delete(rec['Id'])
    except Exception as e:
        print(e)
